# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos extraídos de la imagen:
data = {
    "Operating pressure (bar)": [50, 100, 150, 200, 250, 300],
    "Composite layers": [3, 4, 6, 8, 10, 12],
    "Total tank mass (kg)": [14.5, 17.6, 26.6, 35.9, 45.3, 55.0],
    "Total material cost (USD)": [201, 261, 398, 540, 685, 834]
}

# Crear DataFrame
df = pd.DataFrame(data)
print("Tabla de datos extraídos de la imagen:")
print(df)

# Graficar los datos
plt.figure(figsize=(10, 6))

# Ejemplo de gráfico: 
# En este ejemplo graficamos la masa total del tanque y el costo total en función de la presión operativa.
plt.plot(df["Operating pressure (bar)"], df["Total tank mass (kg)"],
         marker="o", linestyle="-", color="blue", label="Total tank mass (kg)")
plt.plot(df["Operating pressure (bar)"], df["Total material cost (USD)"],
         marker="s", linestyle="--", color="red", label="Total material cost (USD)")

plt.xlabel("Operating pressure (bar)")
plt.title("Type III Pressure Variation Example Summary")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Tabla de datos extraídos de la imagen:
#    Operating pressure (bar)  Composite layers  Total tank mass (kg)  \
# 0                        50                 3                  14.5
# 1                       100                 4                  17.6
# 2                       150                 6                  26.6
# 3                       200                 8                  35.9
# 4                       250                10                  45.3
# 5                       300                12                  55.0
#
#    Total material cost (USD)
# 0                        201
# 1                        261
# 2                        398
# 3                        540
# 4                        685
# 5                        834
